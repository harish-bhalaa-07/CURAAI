# %%
from ultralytics import YOLO

model = YOLO('yolov8n-cls.pt')

# %% [markdown]
# Train the Model

# %%
results = model.train(data="F:/Rohit/PROJECT/Sairam/eye/dataset/", epochs=100, imgsz=320,batch=16,close_mosaic=20,dropout=0.3,single_cls=False,optimizer='auto')
# Out:
# New https://pypi.org/project/ultralytics/8.0.173 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.162  Python-3.11.4 torch-2.0.1 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
# ...

# %%
from ultralytics import YOLO

model = YOLO('eye.pt')  


metrics = model.val()  #
metrics.top1   # top1 accuracy
# Out:
# Ultralytics YOLOv8.0.162  Python-3.11.4 torch-2.0.1 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
# YOLOv8n-cls summary (fused): 73 layers, 1438723 parameters, 0 gradients, 3.3 GFLOPs
# WARNING  Dataset 'split=val' not found, using 'split=test' instead.
# train: F:\Rohit\PROJECT\Sairam\eye\dataset\train... found 3119 images in 3 classes
# val: None...
# test: F:\Rohit\PROJECT\Sairam\eye\dataset\test... found 723 images in 3 classes
# val: Scanning F:\Rohit\PROJECT\Sairam\eye\dataset\test... 723 images, 0 corrupt: 100%|██████████| 723/723 [00:00<?, ?it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 46/46 [00:09<00:00,  4.87it/s]
#                    all          1          1
# Speed: 0.8ms preprocess, 11.4ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to runs\classify\val
# 1.0

# %%
model = YOLO("F:/Rohit/PROJECT/Sairam/pneumonia/runs/classify/train11/weights/last.pt")
model.train(resume=True)

# %%
from PIL import Image
from ultralytics import YOLO


model = YOLO('best.pt')

results = model('glaucoma.jpeg')  

# Show the results
for r in results:
    im_array = r.plot()  # plot a BGR numpy array of predictions
    im = Image.fromarray(im_array[..., ::-1])  # RGB PIL image
    im.show()  # show image
    im.save('results.jpg')  # save image
# Out:
# image 1/1 f:\Rohit\PROJECT\Sairam\eye\glaucoma.jpeg: 320x320 glaucoma 1.00, normal 0.00, cataract 0.00, 40.7ms
# Speed: 2.0ms preprocess, 40.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 320)
